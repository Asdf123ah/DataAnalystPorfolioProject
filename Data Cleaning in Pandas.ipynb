# %% [markdown]
# # Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(r'/home/jonathan/Downloads/Customer Call List.xlsx')

# %%
df = df.drop_duplicates()

# %%
df = df.drop(columns = 'Not_Useful_Column')

# %%
df['Last_Name'] = df['Last_Name'].str.lstrip('/')
df['Last_Name'] = df['Last_Name'].str.lstrip('...')
df['Last_Name'] = df['Last_Name'].str.rstrip('_')

# %%
#df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]', '', regex = True)

#df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

#df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))

#df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

#df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
#df['Phone_Number'] = df['Phone_Number'].str.replace('Na--', '')
#df

# %%
df[['Street_Address', 'State', 'Zip_Code']] = df["Address"].str.split(',', n = 2, expand = True)

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes', 'Y')

df['Paying Customer'] = df['Paying Customer'].str.replace('No', 'N')

# %%
df['Do_Not_Contact'] = df['Paying Customer'].str.replace('Yes', 'Y')

df['Do_Not_Contact'] = df['Paying Customer'].str.replace('No', 'N')

# %%
#df = df.replace('N/a', '')
#df = df.replace('NaN', '')
#df
#df = df.fillna('')

# %%
for x in df.index:
    if df.loc[x, 'Do_Not_Contact'] == 'Y':
        df.drop(x, inplace = True)
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White                  298 Drugs Driveway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 18        1019      Creed      Braton
#
#    Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 1                N              N   93 West Main Street
# 2                N              N    298 Drugs Driveway
# 6                N              N     1209 South Street
# 7                N              N         98 Clue Drive
# 14               N              N         214 HR Avenue
# 15               N              N  2395 Hogwarts Avenue
# 18

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White                  298 Drugs Driveway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 18        1019      Creed      Braton
#
#    Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 1                N              N   93 West Main Street
# 2                N              N    298 Drugs Driveway
# 6                N              N     1209 South Street
# 7                N              N         98 Clue Drive
# 14               N              N         214 HR Avenue
# 15               N              N  2395 Hogwarts Avenue
# 18

# %%
df.reset_index(drop = True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1002       Abed       Nadir  123-643-9775   93 West Main Street
# 1        1003     Walter       White                  298 Drugs Driveway
# 2        1007       Jeff      Winger                   1209 South Street
# 3        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 4        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 5        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 6        1019      Creed      Braton
#
#   Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 0               N              N   93 West Main Street
# 1               N              N    298 Drugs Driveway
# 2               N              N     1209 South Street
# 3               N              N         98 Clue Drive
# 4               N              N         214 HR Avenue
# 5               N              N  2395 Hogwarts Avenue
# 6
